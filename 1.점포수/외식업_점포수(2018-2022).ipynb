# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
store_all = pd.read_csv("C:/Sosang/1.점포수/외식업_점포수(2018-2022).csv", encoding='cp949', thousands=',') # 쉼표 제거와 동시에 int값으로 변경하여 불러오기
store_all
# Out:
#         년도   2018년   2019년   2020년   2021년   2022년
# 0   서울시 전체  569353  561436  570418  582988  592256
# 1      종로구   27999   27823   27741   27588   27859
# 2       중구   26485   26313   26517   26099   26144
# 3      용산구   20016   20256   20556   20745   21509
# 4      성동구   15770   16276   17021   17912   18392
# 5      광진구   20458   20181   20543   21185   21575
# 6     동대문구   20382   19486   19576   19870   20165
# 7      중랑구   17416   16676   16857   17237   17549
# 8      성북구   19413   18496   18556   19024   19368
# 9      강북구   15828   15120   15405   15670   15753
# 10     도봉구   12239   11854   12014   12326   12365
# 11     노원구   18377   18045   18337   18666   18717
# 12     은평구   18396   18058   18537   19276   19584
# 13    서대문구   18218   17613   17676   17898   18142
# 14     마포구   36228   36500   36989   37900   39104
# 15     양천구   16121   15560   15922   16431   16589
# 16     강서구   24617   25575   26559   28011   28893
# ...

# %%
store_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      26 non-null     object
#  1   2018년   26 non-null     int64
#  2   2019년   26 non-null     int64
#  3   2020년   26 non-null     int64
#  4   2021년   26 non-null     int64
#  5   2022년   26 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
store_all.describe()
# Out:
#                2018년          2019년          2020년          2021년  \
# count      26.000000      26.000000      26.000000      26.000000
# mean    43796.384615   43187.384615   43878.307692   44845.230769
# std    107517.394606  106047.865712  107747.181957  110124.482690
# min     12239.000000   11854.000000   12014.000000   12326.000000
# 25%     17616.500000   17398.500000   17391.000000   17901.500000
# 50%     20420.000000   19833.500000   20059.500000   20307.500000
# 75%     27620.500000   27445.500000   27445.500000   27905.250000
# max    569353.000000  561436.000000  570418.000000  582988.000000
#
#                2022년
# count      26.000000
# mean    45558.153846
# std    111882.854415
# min     12365.000000
# 25%     18204.500000
# 50%     20841.500000
# 75%     28634.500000
# max    592256.000000

# %%
plt.figure(figsize = (5, 5))
plt.boxplot([store_all['2018년'].loc[1:],store_all['2019년'].iloc[1:],store_all['2020년'].iloc[1:], store_all['2021년'].iloc[1:],store_all['2022년'].iloc[1:]])
plt.show()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

xdata = ['2018','2019','2020','2021','2022']
ydata = store_all.loc[0,'2018년':'2022년']
plt.plot(xdata, ydata)
plt.xlabel('년도')
plt.ylabel('외식업 점포수')
# Out:
# Text(0, 0.5, '외식업 점포수')
